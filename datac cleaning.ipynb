# %% [markdown]
# Day2(21/04/2026)

# %% [markdown]
#  # car data analysis

# %% [markdown]
# import pandas

# %%
import pandas as pd

# %% [markdown]
# enter the dataset

# %%
import pandas as pd
df=pd.read_csv("car details v3 - car details v3.csv")
print(df)
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %% [markdown]
# IDENTIFY THE DETAILS OF THE DATASET

# %%
df.head(5)
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
df.tail(5)
# Out:
#                         name  year  selling_price  km_driven    fuel  \
# 8123       Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124   Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125  Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126         Tata Indigo CR4  2013         290000      25000  Diesel
# 8127         Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner     mileage   engine  \
# 8123  Individual       Manual           First Owner   18.5 kmpl  1197 CC
# 8124  Individual       Manual  Fourth & Above Owner   16.8 kmpl  1493 CC
# 8125  Individual       Manual           First Owner   19.3 kmpl  1248 CC
# 8126  Individual       Manual           First Owner  23.57 kmpl  1396 CC
# 8127  Individual       Manual           First Owner  23.57 kmpl  1396 CC
#
#       max_power                     torque  seats
# 8123  82.85 bhp           113.7Nm@ 4000rpm    5.0
# ...

# %%
df.sample(5)
# Out:
#                                      name  year  selling_price  km_driven  \
# 4141         Skoda Rapid 1.6 TDI Ambition  2012         290000      80000
# 3593                 Hyundai Verna 1.6 SX  2011         450000      96000
# 7507  Volkswagen Ameo 1.5 TDI Comfortline  2020         800000      25000
# 3644         Mahindra Scorpio S2 9 Seater  2015         720000      80000
# 4832      Skoda Rapid 1.6 MPI AT Elegance  2016         645000      11000
#
#         fuel seller_type transmission                 owner     mileage  \
# 4141  Diesel  Individual       Manual          Second Owner   20.5 kmpl
# 3593  Diesel  Individual       Manual  Fourth & Above Owner  22.32 kmpl
# 7507  Diesel  Individual       Manual           First Owner  21.66 kmpl
# 3644  Diesel  Individual       Manual           First Owner   15.4 kmpl
# 4832  Petrol      Dealer    Automatic           First Owner   14.3 kmpl
#
#        engine   max_power                 torque  seats
# ...

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')

# %%
df.shape
# Out:
# (8128, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
df.dtypes
# Out:
# name              object
# year               int64
# selling_price      int64
# km_driven          int64
# fuel              object
# seller_type       object
# transmission      object
# owner             object
# mileage           object
# engine            object
# max_power         object
# torque            object
# seats            float64
# dtype: object

# %%
df.iloc[1:4]
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
#
#                      torque  seats
# 1       250Nm@ 1500-2500rpm    5.0
# 2     12.7@ 2,700(kgm@ rpm)    5.0
# 3  22.4 kgm at 1750-2750rpm    5.0

# %% [markdown]
# analysis & remove duplication

# %%
df.duplicated().sum()
# Out:
# np.int64(1202)

# %%
df[df.duplicated()]
# Out:
#                                           name  year  selling_price  \
# 291                   Hyundai Grand i10 Sportz  2017         450000
# 296                           Maruti Swift VXI  2012         330000
# 370   Jaguar XE 2016-2019 2.0L Diesel Prestige  2017        2625000
# 371                              Lexus ES 300h  2019        5150000
# 372             Jaguar XF 2.0 Diesel Portfolio  2017        3200000
# ...                                        ...   ...            ...
# 7987             Renault Captur 1.5 Diesel RXT  2018        1265000
# 7988                  Maruti Ciaz Alpha Diesel  2019        1025000
# 8117                    Maruti Swift Dzire VDI  2015         625000
# 8126                           Tata Indigo CR4  2013         290000
# 8127                           Tata Indigo CR4  2013         290000
#
#       km_driven    fuel seller_type transmission         owner     mileage  \
# ...

# %%
df=df.drop_duplicates()

# %% [markdown]
# SELECT ALL SELLING PRICE GREATER THAN 2000000

# %%
df[df["selling_price"]>2000000]
# Out:
#                                       name  year  selling_price  km_driven  \
# 41      Jeep Compass 1.4 Limited Plus BSIV  2019        2100000       5000
# 82                  BMW X1 sDrive20i xLine  2016        2500000      30000
# 131             Audi Q5 35TDI Premium Plus  2018        3975000      31800
# 132                          Lexus ES 300h  2019        5150000      20000
# 133         Jaguar XF 2.0 Diesel Portfolio  2017        3200000      45000
# ...                                    ...   ...            ...        ...
# 7797  Mercedes-Benz B Class B200 CDI Sport  2015        2051000      35000
# 7808      Mercedes-Benz M-Class ML 350 CDI  2014        2575000      70000
# 7922            Skoda Kodiaq 2.0 TDI Style  2018        2800000      40000
# 7930         Volvo S90 D4 Inscription BSIV  2019        5500000      17000
# 7931    Ford Endeavour 2.2 Titanium AT 4X2  2016        2100000      85000
#
# ...

# %% [markdown]
# SELECTING HIGH-VALUE RECORDS (YEAR>2016&PRICE>2000000)

# %%
df[(df["year"]>2016)&(df["selling_price"]>2000000)]
# Out:
#                                      name  year  selling_price  km_driven  \
# 41     Jeep Compass 1.4 Limited Plus BSIV  2019        2100000       5000
# 131            Audi Q5 35TDI Premium Plus  2018        3975000      31800
# 132                         Lexus ES 300h  2019        5150000      20000
# 133        Jaguar XF 2.0 Diesel Portfolio  2017        3200000      45000
# 134       Jeep Wrangler 2016-2019 3.6 4X4  2017        4100000      17000
# ...                                   ...   ...            ...        ...
# 7516       Volvo XC60 Inscription D5 BSIV  2018        5500000      50000
# 7522  Toyota Innova Crysta 2.8 ZX AT BSIV  2017        2175000      50000
# 7661      Toyota Fortuner 2.8 4WD AT BSIV  2020        3200000       3000
# 7922           Skoda Kodiaq 2.0 TDI Style  2018        2800000      40000
# 7930        Volvo S90 D4 Inscription BSIV  2019        5500000      17000
#
#         fuel seller_type transmission        owner     mileage   engine  \
# ...

# %%
df[["mileage_value","mileage_unit"]]=df["mileage"].str.split(" ",expand=True)

# %%
df
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# ...                                 ...   ...            ...        ...
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                  Hyundai i20 Magna  2013         320000     110000
# 8124              Hyundai Verna CRDi SX  2007         135000     119000
# 8125             Maruti Swift Dzire ZDi  2009         382000     120000
#
#         fuel seller_type transmission                 owner     mileage  \
# ...

# %%
df[["engine_value","engine_unit"]]=df["engine"].str.split(" ",expand=True)

# %%
df
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# ...                                 ...   ...            ...        ...
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                  Hyundai i20 Magna  2013         320000     110000
# 8124              Hyundai Verna CRDi SX  2007         135000     119000
# 8125             Maruti Swift Dzire ZDi  2009         382000     120000
#
#         fuel seller_type transmission                 owner     mileage  \
# ...

# %% [markdown]
# CHECKING FOR MISSING VALUES IN A DATASET

# %%
df.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          208
# engine           208
# max_power        205
# torque           209
# seats            208
# mileage_value    208
# mileage_unit     208
# engine_value     208
# engine_unit      208
# dtype: int64

# %% [markdown]
# drop duplication

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# ...                                 ...   ...            ...        ...
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                  Hyundai i20 Magna  2013         320000     110000
# 8124              Hyundai Verna CRDi SX  2007         135000     119000
# 8125             Maruti Swift Dzire ZDi  2009         382000     120000
#
#         fuel seller_type transmission                 owner     mileage  \
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
 df=df.dropna(subset=["mileage","engine","max_power","torque","seats"])

# %%
df
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# ...                                 ...   ...            ...        ...
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                  Hyundai i20 Magna  2013         320000     110000
# 8124              Hyundai Verna CRDi SX  2007         135000     119000
# 8125             Maruti Swift Dzire ZDi  2009         382000     120000
#
#         fuel seller_type transmission                 owner     mileage  \
# ...

# %% [markdown]
# CHECKING FOR MISSING VALUES IN A DATASET

# %%
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# torque           0
# seats            0
# mileage_value    0
# mileage_unit     0
# engine_value     0
# engine_unit      0
# dtype: int64

# %%
df["selling_price"]=df["selling_price"].fillna(df["selling_price"].mean())
# Out:
# C:\Users\INTERN\AppData\Local\Temp\ipykernel_10996\429306130.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["selling_price"]=df["selling_price"].fillna(df["selling_price"].mean())

# %%
df["name"].str.lower()
# Out:
# 0                  maruti swift dzire vdi
# 1            skoda rapid 1.5 tdi ambition
# 2                honda city 2017-2020 exi
# 3               hyundai i20 sportz diesel
# 4                  maruti swift vxi bsiii
#                       ...
# 8121    maruti wagon r vxi bs iv with abs
# 8122           hyundai i20 magna 1.4 crdi
# 8123                    hyundai i20 magna
# 8124                hyundai verna crdi sx
# 8125               maruti swift dzire zdi
# Name: name, Length: 6717, dtype: object

# %% [markdown]
# SEPARATE THE VALUES AND UNITS INTO DISTINCT COLUMNS

# %%
df[["mileage_value","mileage_unit"]]=df["mileage"].str.split(" ",expand=True)
# Out:
# C:\Users\INTERN\AppData\Local\Temp\ipykernel_10996\2646336915.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["mileage_value","mileage_unit"]]=df["mileage"].str.split(" ",expand=True)

# %%
df
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# ...                                 ...   ...            ...        ...
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                  Hyundai i20 Magna  2013         320000     110000
# 8124              Hyundai Verna CRDi SX  2007         135000     119000
# 8125             Maruti Swift Dzire ZDi  2009         382000     120000
#
#         fuel seller_type transmission                 owner     mileage  \
# ...

# %%
df[["engine_value","engine_unit"]]=df["engine"].str.split(" ",expand=True)
# Out:
# C:\Users\INTERN\AppData\Local\Temp\ipykernel_10996\4011839244.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["engine_value","engine_unit"]]=df["engine"].str.split(" ",expand=True)

# %%
df
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# ...                                 ...   ...            ...        ...
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                  Hyundai i20 Magna  2013         320000     110000
# 8124              Hyundai Verna CRDi SX  2007         135000     119000
# 8125             Maruti Swift Dzire ZDi  2009         382000     120000
#
#         fuel seller_type transmission                 owner     mileage  \
# ...

# %% [markdown]
# CHECKING FOR MISSING VALUES IN A DATASET

# %%
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# torque           0
# seats            0
# mileage_value    0
# mileage_unit     0
# engine_value     0
# engine_unit      0
# dtype: int64

# %%
df["selling_price"]=df["selling_price"].fillna(df["selling_price"].mean())
# Out:
# C:\Users\INTERN\AppData\Local\Temp\ipykernel_10996\1862354553.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["selling_price"]=df["selling_price"].fillna(df["selling_price"].mean())

# %%
df
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# ...                                 ...   ...            ...        ...
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                  Hyundai i20 Magna  2013         320000     110000
# 8124              Hyundai Verna CRDi SX  2007         135000     119000
# 8125             Maruti Swift Dzire ZDi  2009         382000     120000
#
#         fuel seller_type transmission                 owner     mileage  \
# ...

# %% [markdown]
# CONVERT STRING COLUMNS TO FLOATS

# %%
df['float_mileage_value']=df['mileage_value'].astype(float)
# Out:
# C:\Users\INTERN\AppData\Local\Temp\ipykernel_10996\871599270.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['float_mileage_value']=df['mileage_value'].astype(float)

# %%
df
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# ...                                 ...   ...            ...        ...
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                  Hyundai i20 Magna  2013         320000     110000
# 8124              Hyundai Verna CRDi SX  2007         135000     119000
# 8125             Maruti Swift Dzire ZDi  2009         382000     120000
#
#         fuel seller_type transmission                 owner     mileage  \
# ...

# %%
df['float_engine_value']=df['engine_value'].astype(float)
# Out:
# C:\Users\INTERN\AppData\Local\Temp\ipykernel_10996\2858377357.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['float_engine_value']=df['engine_value'].astype(float)

# %%
df
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# ...                                 ...   ...            ...        ...
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                  Hyundai i20 Magna  2013         320000     110000
# 8124              Hyundai Verna CRDi SX  2007         135000     119000
# 8125             Maruti Swift Dzire ZDi  2009         382000     120000
#
#         fuel seller_type transmission                 owner     mileage  \
# ...

# %% [markdown]
# CALCULATE THE MEAN,MEDIAN,MODE,MAX & MIN FOR A DATASET

# %%
df["selling_price"].mean()
# Out:
# np.float64(526385.9970224802)

# %%
df["selling_price"].median()
# Out:
# 420000.0

# %%
df["selling_price"].max()
# Out:
# 10000000

# %%
df["selling_price"].min()
# Out:
# 29999

# %%
df["selling_price"].mode()
# Out:
# 0    300000
# Name: selling_price, dtype: int64

# %%
df["km_driven"].min()
# Out:
# 1

# %%
df["km_driven"].max()
# Out:
# 2360457

# %%
df["km_driven"].median()
# Out:
# 68203.0

# %%
df["km_driven"].mode()
# Out:
# 0    120000
# Name: km_driven, dtype: int64

# %%
df["km_driven"].mean()
# Out:
# np.float64(73398.33765073694)

# %%
df.to_csv("data_cleaning.csv",index=False)
